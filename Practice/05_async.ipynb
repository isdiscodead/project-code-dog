# %% [markdown]
# ## 비동기 Async
# 일반적인 함수는 동기적( synchronous )으로, 순차적 작동함
#
# -> 해당 함수가 실행이 끝날 때까지 다른 일을 하지 않음
#
# -> 해당 함수가 컴퓨팅 자원의 일부만 사용한다면 나머지 컴퓨팅 자원들은 낭비됨

# %%
import time

def foo():
    res = 0

    for i in range(1, 10):
        res += i
        print(res)
        time.sleep(1)

    return res

start = time.time()

foo()
foo()

end = time.time()

over_time = round(end - start, 3)
print(f'걸린 시간 : {over_time}')
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 걸린 시간 : 18.074

# %%
import time 
import asyncio # local에서 돌려야 함 ~~ 

# async 키워드를 사용해 코루틴 형태로 실행해야 함 
async def foo():
    res = 0

    for i in range(1, 10):
        res += i
        print(res)
        # await 키워드 사용 시 뒤의 코드도 코루틴이어야 함 
        await asyncio.sleep(1) # 1초 동안 일을 못함 -> 2번째 foo 함수로 진행을 넘김

    return res

start = time.time()

# 코루틴 형식을 사용하기 위해서는 이들을 관리할 루프가 필요함 
loop = asyncio.get_event_loop()
loop.run_until_complete(asyncio.gather(foo(), foo())) # gather로 여러 개의 코루틴 실행 
# asyncio.run(asyncio.wait([foo(), foo()]))로 루프 없이 사용도 가능 
loop.close()

end = time.time()

over_time = round(end - start, 3)
print(f'걸린 시간 : {over_time}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb 셀 4 in <module>
#      <a href='vscode-notebook-cell:/Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a> start = time.time()
#      <a href='vscode-notebook-cell:/Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> loop = asyncio.get_event_loop()
# ---> <a href='vscode-notebook-cell:/Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> loop.run_until_complete(asyncio.gather(foo(), foo()))
#      <a href='vscode-notebook-cell:/Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> loop.close()
#      <a href='vscode-notebook-cell:/Users/isdiscodead/Documents/UDR/ProjectCodeDog/Practice/05_async.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> end = time.time()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:618, in BaseEventLoop.run_until_complete(self, future)
#     607 """Run until the Future is done.
#     608
#     609 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     615 Return the Future's result, or raise its exception.
#     616 """
#     617 self._check_closed()
# --> 618 self._check_running()
#     620 new_task = not futures.isfuture(future)
#     621 future = tasks.ensure_future(future, loop=self)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py:578, in BaseEventLoop._check_running(self)
#     576 def _check_running(self):
#     577     if self.is_running():
# --> 578         raise RuntimeError('This event loop is already running')
#     579     if events._get_running_loop() is not None:
#     580         raise RuntimeError(
#     581             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# 1
# 1
# 3
# 3
# 6
# 6
# 10
# 10
# 15
# 15
# 21
# 21
# 28
# 28
# 36
# 36
# 45
# 45
